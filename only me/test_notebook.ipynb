# %%
# input all links as a csv file

import pandas as pd

# Load the CSV file
all_links_input = pd.read_csv('C:\\Users\\becod\\AI\\my-projects\\Majid_immoeliza_scraping\\links\\all_links.csv', on_bad_lines='skip')

# Show the first few rows of the data
all_links_input
# Out:
#      Property ID Postal code          Locality name         Price  \
# 0       20239719        4102                seraing        325000
# 1       20236298        2660                hoboken        249900
# 2       20236289        2018         antwerpen-2018        375000
# 3       20237641        4100                seraing  133000335000
# 4       20239456        1082  berchem-sainte-agathe  149000382000
# ..           ...         ...                    ...           ...
# 175     20030209        6120               nalinnes        140000
# 176     11181379        6142                leernes        189000
# 177      9885760        5660            mariembourg        700000
# 178     10964687        6040                  jumet         70000
# 179     11367732        6000              charleroi        199000
#
#     Type of property Number of rooms  Living area  Equipped kitchen  \
# 0       Apartment\n       2 bedrooms         89.0                 1
# ...
