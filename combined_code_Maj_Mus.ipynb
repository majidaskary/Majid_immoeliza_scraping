# %% [markdown]
# combined code

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import csv

# ---------------------------------------------------------------------------------------------------
# immoweb house and apartment fore sale's page
immoweb_sale_link = 'https://www.immoweb.be/en/search/house-and-apartment/for-sale?countries=BE&page=1&orderBy=relevance'

# ---------------------------------------------------------------------------------------------------
# generating the links of 333 pages 

first_group_pages_link_sale = 'https://www.immoweb.be/en/search/house-and-apartment/for-sale?countries=BE&amp%3BorderBy=relevance&amp%3Bpage=2'
p = 1
last_p = 333
group_pages_link_sale = []

# adding 1st page in 1st cell of list
group_pages_link_sale.append(first_group_pages_link_sale)

for p in range(2,last_p+1):  
    group_pages_link_sale.append(first_group_pages_link_sale +"&page=" + str(p))   # adding the link + new number of pages

#group_pages_link_sale

# ---------------------------------------------------------------------------------------------------
# extracting all linkes (+10000 links) for sale from immoweb// by group_pages_link_sale

all_links = []              



group_pages_link_sale_test = group_pages_link_sale[:33]

for l in group_pages_link_sale_test:          # a loop to scrape that 333 group pages of immoweb

    session = requests.Session()               
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }
    response = session.get(l, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    for tag_a in soup.find_all('a', class_="card__title-link", href=True):   # extracting all item links paer group page
        all_links.append(tag_a['href'])

#all_links 

# ---------------------------------------------------------------------------------------------------


# List_url = [
#     "https://www.immoweb.be/en/classified/penthouse/for-sale/etterbeek/1040/20232667",
#     "https://www.immoweb.be/en/classified/house/for-sale/kortrijk/8500/20234460",
#     "https://www.immoweb.be/nl/zoekertje/huis/te-koop/amay/4540/20215296",
#     "https://www.immoweb.be/en/classified/house/for-sale/wavre/1300/20231046",
#     "https://www.immoweb.be/en/classified/apartment/for-sale/saint-gilles/1060/20234144",
# ]

def request_url(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
    }
    req = requests.get(url, headers=headers)
    soup = BeautifulSoup(req.content, "html.parser")
    property_details = []

    try:
        html = soup.find("meta", {"property": "og:url"}).get("content")
        html_list = html.split("/")
        Property_ID = html_list[-1]
    except:
        Property_ID = None
    try:
        postal_code = html_list[-2]
    except:
        postal_code = None
    try:
        locality = html_list[-3]
    except:
        locality = None
    try:
        home_meta_info = soup.find_all("div", {"class": "grid__item desktop--9"})

        price = (
            home_meta_info[0]
            .find("p", {"class": "classified__price"})
            .find_all("span", {"class": "sr-only"})[0]
         .text.strip()
        )
        print(price)

        if price:
            price = re.sub(r"\D", "", price)  # remoning all non number characters
            price = int(price) if price else None  # converting to a number if its not empty

    except:
        price = None
    try:
        Type_of_property = (
            home_meta_info[0]
            .find("h1", {"class": "classified__title"})
            .text.strip()[0:11]
        )  # the second [0:11] just to return the property type
    except:
        Type_of_property = None
    try:
        home_prop_info = soup.find_all("div", {"class": "text-block__body"})[
            0
        ].find_all("div", {"class": "overview__column"})
        bed_rooms = (
            home_prop_info[0]
            .find_all("div", {"class": "overview__item"})[0]
            .find_all("span", {"class": "overview__text"})[0]
            .text.strip()
        )
    except:
        bed_rooms = None
    try:
        space = (
            home_prop_info[1]
            .find_all("div", {"class": "overview__item"})[0]
            .find_all("span", {"class": "overview__text"})[0]
            .text.strip()
        )
        space = re.findall(r"\d+", space)[0]  # Extract only the digits
    except:
        space = None
        
    ######################## check this one again for different name ######################## try elif on the original one
    try:
        kitchen_keywords = (
            "Kitchen type",
            "Type of kitchen",
        )  # as sometimes it has one of these names
        kitchen_th = soup.find(
            "th", string=lambda x: x and x.strip() in kitchen_keywords
        )
        if kitchen_th:
            kitchen = kitchen_th.find_next_sibling("td").contents[0].strip()
            print(kitchen)

            # Now, check for the kitchen types you're interested in
            if kitchen in (
                "Installed",
                "Installed",
                "Hyper equipped",
                "USA  Hyper equipped",
                "Semi equipped",
                "USA hyper equipped",
            ):
                kitchen_type = 1
            else:
                kitchen_type = 0
        else:
            kitchen_type = (
                0  # Default value if 'Kitchen type' or 'Type of kitchen' not found
            )
    except:
        kitchen_type = None
    # Building cindition
    try:
        building_condition_header = soup.find(
            "th", string=lambda x: x and x.strip() == "Building condition"
        ).find_parent("tr")

        building_condition = (
            building_condition_header.find("td", class_="classified-table__data")
            .contents[0]
            .strip()
        )
    except:
        building_condition = None
    # Number of facades   Number of facades
    ############################# the same problem as kitchen, it might be named "Number of facades" #############
    try:
        facades = (
            soup.find("th", string=lambda x: x and x.strip() == "Number of frontages")
            .find_next_sibling("td")
            .contents[0]
            .strip()
        )

        if facades:
            Number_of_facades = facades
        else:
            Number_of_facades = 0
    except:
        Number_of_facades = None
        
    # Furnished
    ############################# the same problem as kitchen, it might be named "State of the building" #############
    try:
        Furnished = (
            soup.find("th", string=lambda x: x and x.strip() == "Furnished")
            .find_next_sibling("td")
            .contents[0]
            .strip()
        )
        if Furnished == "Yes":
            Furnished = 1
        else:
            Furnished = 0
    except:
        Furnished = None
    # open fire space
    try:
        Open_fire = (
            soup.find("th", string=lambda x: x and x.strip() == "How many fireplaces?")
            .find_next_sibling("td")
            .contents[0]
            .strip()
        )
        if Open_fire:
            Open_fire = 1
        else:
            Open_fire = 0
    except:
        Open_fire = None
    # Swimming_pool
    try:
        Swimming_pool = (
            soup.find("th", string=lambda x: x and x.strip() == "Swimming pool")
            .find_next_sibling("td")
            .contents[0]
            .strip()
        )
        if Swimming_pool == "Yes":
            Swimming_pool = 1
        else:
            Swimming_pool = 0
    except:
        Swimming_pool = None
    # Garden
    ############################### Different name "Garden area" ###########################
    try:
        garden = (
            soup.find("th", string=lambda x: x and x.strip() == "Garden surface")
            .find_next_sibling("td")
            .contents[0]
            .strip()
        )
        if garden:
            garden = garden
        else:
            garden = None
    except:
        garden = None
    # Terrace
    ################################## It might have value only "Yes" or differnt name like "Terrace surface area" #########################
    try:
        Terrace = (
            soup.find("th", string=lambda x: x and x.strip() == "Terrace surface")
            .find_next_sibling("td")
            .contents[0]
            .strip()
        )
        if Terrace:
            Terrace = Terrace
        else:
            Terrace = None

    except:
        Terrace = None

    property_details.append(
        {
            "Property ID": Property_ID,
            "Postal code": postal_code,
            "Locality name": locality,
            "Price": price,
            "Type of property": Type_of_property,
            "Number of rooms": bed_rooms,
            "Living area": space,
            "Equipped kitchen": kitchen_type,
            "State of building": building_condition,
            "Number of facades": Number_of_facades, #facades,
            "Furnished": Furnished,
            "Open fire": Open_fire,
            "Swimming pool": Swimming_pool,
            "Garden (m²)": garden,
            "Terrace (m²)": Terrace,
        }
    )

    return property_details


# Assuming List_url contains your URLs
all_property_details = []
for url in all_links: #List_url:
    all_property_details.extend(request_url(url))

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(all_property_details)

# Save the DataFrame to a CSV file
df.to_csv(
    "C:\\Users\\becod\\AI\\my-projects\\immoeliza_scraping_Majid\\property_details.csv",
    index=False,
    encoding="utf-8",
)

print("extracted data saved in CSv file")
# Out:
# 249900€
# 375000€
# Installed
# From 159325€ To 447375€
# From 159325€ To 447375€
# From 188000€ To 265000€
# From 230000€ To 480000€
# From 230000€ To 480000€
# From 260000€ To 265000€
# From 260250€ To 304000€
# From 265000€ To 570000€
# From 269000€ To 469000€
# From 273700€ To 382150€
# From 273700€ To 382500€
# From 276500€ To 332000€
# From 286000€ To 462000€
# From 299500€ To 319000€
# From 301948€ To 556453€
# From 310000€ To 400000€
# From 310000€ To 400000€
# From 310000€ To 400000€
# From 320000€ To 465000€
# From 347400€ To 394600€
# 349000€
# From 360000€ To 430000€
# From 365000€ To 397000€
# From 370000€ To 396000€
# From 404500€ To 450000€
# From 455600€ To 542214€
# From 458000€ To 465000€
# From 481000€ To 521000€
# 260000€
# Installed
# 435000€
# Hyper equipped
# From 279000€ To 849000€
# 172000€
# Installed
# 165000€
# 229000€
# 240000€
# Installed
# 415000€
# Installed
# 289000€
# 239000€
# 499000€
# USA hyper equipped
# 725000€
# Installed
# 379000€
# Installed
# 269000€
# Semi equipped
# 359000€
# Installed
# 180000€
# 1195000€
# Hyper equipped
# 549000€
# Installed
# 350000€
# Installed
# 311000€
# 219000€
# Hyper equipped
# 299000€
# Semi equipped
# 119000€
# 265000€
# Not installed
# 250000€
# Installed
# 345124€
# Hyper equipped
# 450000€
# 295000€
# 295000€
# 2250000€
# From 481000€ To 521000€
# From 481000€ To 506000€
# From 498000€ To 585000€
# From 679000€ To 725000€
# 225000€
# Installed
# 225000€
# Installed
# 225000€
# Semi equipped
# 229000€
# 550000€
# Installed
# From 169500€ To 389000€
# From 169500€ To 389000€
# From 188000€ To 460000€
# From 188000€ To 460000€
# From 235000€ To 340000€
# From 245000€ To 650000€
# From 249000€ To 349000€
# From 260000€ To 265000€
# From 265000€ To 1495000€
# From 265000€ To 500000€
# From 265000€ To 500000€
# From 295000€ To 445000€
# From 295000€ To 445000€
# From 315000€ To 390000€
# From 315000€ To 390000€
# From 315000€ To 319000€
# From 325000€ To 410000€
# 335000€
# From 337000€ To 383011€
# 369000€
# From 420000€ To 495000€
# 345124€
# Hyper equipped
# 450000€
# 295000€
# 295000€
# 2250000€
# 395000€
# Hyper equipped
# 199000€
# Installed
# 349000€
# 425000€
# 235000€
# 480000€
# Semi equipped
# 469000€
# Installed
# 315000€
# Installed
# 409000€
# Installed
# 125000€
# 365000€
# 198000€
# Semi equipped
# 542000€
# Installed
# 1495000€
# Hyper equipped
# 15000€
# Installed
# 435000€
# Installed
# 265000€
# Hyper equipped
# 498000€
# Semi equipped
# 165000€
# Installed
# 125000€
# Installed
# 695000€
# Installed
# From 208000€ To 404000€
# From 220000€ To 525000€
# 346950€
# From 366000€ To 425000€
# From 425000€ To 1100000€
# 455000€
# 473000€
# From 485000€ To 580000€
# 485000€
# From 534000€ To 585000€
# 543000€
# 189000€
# 389900€
# Hyper equipped
# 389900€
# Hyper equipped
# 295000€
# Installed
# 225000€
# 265000€
# Hyper equipped
# 765000€
# Hyper equipped
# From 117800€ To 189800€
# From 188000€ To 460000€
# From 188000€ To 460000€
# 227749€
# 227749€
# From 245000€ To 550050€
# From 249000€ To 399500€
# From 260000€ To 465000€
# From 275000€ To 329000€
# From 297000€ To 314000€
# From 299000€ To 479000€
# 307649€
# From 310000€ To 400000€
# 365000€
# From 399000€ To 426000€
# From 419000€ To 425000€
# From 366000€ To 425000€
# 225000€
# 595000€
# Installed
# 209000€
# Installed
# 334000€
# USA hyper equipped
# 55000€
# Installed
# 199000€
# Installed
# 475000€
# Hyper equipped
# 89500€
# Semi equipped
# 499000€
# Installed
# 315000€
# Installed
# 315000€
# Installed
# 386000€
# Installed
# 305000€
# Installed
# 1490000€
# Installed
# 1490000€
# Installed
# 799000€
# Installed
# 269000€
# Semi equipped
# 290000€
# Semi equipped
# 235000€
# Semi equipped
# 689000€
# Installed
# 175000€
# Semi equipped
# 265000€
# Installed
# 425000€
# Installed
# 429000€
# Installed
# 259000€
# Hyper equipped
# 175000€
# Installed
# 179000€
# Semi equipped
# 235000€
# Hyper equipped
# 415000€
# 219000€
# Semi equipped
# 269000€
# Installed
# 289000€
# Installed
# 199000€
# Semi equipped
# 370000€
# Semi equipped
# 199000€
# Not installed
# 220000€
# Installed
# 235000€
# Installed
# 350000€
# Installed
# 215000€
# Installed
# 249000€
# Semi equipped
# 685000€
# Hyper equipped
# 459000€
# Hyper equipped
# 574000€
# Installed
# 589000€
# Hyper equipped
# 595000€
# Semi equipped
# 925000€
# USA uninstalled
# 925000€
# USA uninstalled
# 925000€
# USA uninstalled
# 630000€
# Installed
# 295000€
# Hyper equipped
# 460000€
# Hyper equipped
# 139000€
# Not installed
# 295000€
# Installed
# 169000€
# Semi equipped
# 350000€
# Hyper equipped
# 450000€
# Semi equipped
# 1950000€
# USA hyper equipped
# 549000€
# Installed
# From 225000€ To 375000€
# 420000€
# 259000€
# 395600€
# Installed
# 233500€
# Installed
# 220000€
# Hyper equipped
# 419000€
# Installed
# 485000€
# Installed
# 239000€
# Installed
# 239000€
# Installed
# 220000€
# 165000€
# Installed
# 269000€
# Installed
# 239000€
# From 260000€ To 265000€
# 260000€
# Installed
# 265000€
# Installed
# 399000€
# Installed
# 295000€
# 284000€
# 89000€
# Semi equipped
# 199000€
# Installed
# 249000€
# 265000€
# 119000€
# 94800€
# Not installed
# 345000€
# 85000€
# Semi equipped
# 149000€
# 249000€
# 525000€
# From 289000€ To 294000€
# From 289000€ To 312000€
# From 320000€ To 850000€
# From 325000€ To 366000€
# From 347551€ To 379551€
# From 355000€ To 374000€
# From 359000€ To 489000€
# From 399000€ To 510000€
# From 405000€ To 444000€
# From 407000€ To 443000€
# From 462500€ To 523500€
# From 472000€ To 478000€
# From 615000€ To 765000€
# 765000€
# From 1200000€ To 1375000€
# 200000€
# Installed
# 239500€
# Installed
# 275000€
# 635000€
# Hyper equipped
# 459000€
# 479000€
# Installed
# 549000€
# 549000€
# 185000€
# Semi equipped
# 235000€
# Semi equipped
# 185000€
# Installed
# 199000€
# Installed
# 279000€
# Installed
# 285000€
# Semi equipped
# 319000€
# Installed
# 350000€
# 520000€
# 499000€
# 695000€
# 359000€
# 549000€
# 285000€
# Semi equipped
# 219000€
# Installed
# 178000€
# Installed
# 1690000€
# 175000€
# Installed
# 417630€
# 219000€
# Installed
# 195000€
# Installed
# 299000€
# Semi equipped
# 329000€
# Installed
# 139000€
# Installed
# 275000€
# 445000€
# Hyper equipped
# 465000€
# Installed
# 419000€
# Installed
# 785000€
# Hyper equipped
# 339000€
# Semi equipped
# 395500€
# 165000€
# Semi equipped
# 365000€
# Installed
# 275000€
# 430000€
# 670000€
# 275000€
# Installed
# 435000€
# Semi equipped
# 185000€
# Semi equipped
# 195000€
# Installed
# 269000€
# Not installed
# 215000€
# Installed
# 399000€
# 549950€
# 199000€
# Installed
# 249000€
# Installed
# 575000€
# Installed
# 399000€
# Installed
# 595000€
# From 369000€ To 490000€
# From 376000€ To 549500€
# 348000€
# Installed
# 345000€
# Installed
# 425000€
# Installed
# 245000€
# Installed
# 395000€
# Installed
# 449000€
# Installed
# 539000€
# Installed
# 475000€
# Hyper equipped
# 495000€
# Semi equipped
# 1495000€
# Installed
# 250000€
# Installed
# 1495000€
# Hyper equipped
# 249000€
# Installed
# 260000€
# Installed
# 415000€
# Installed
# 528000€
# Installed
# 420000€
# Hyper equipped
# 199000€
# Installed
# 595000€
# 189000€
# Not installed
# 135000€
# 169000€
# 299000€
# 219000€
# Installed
# 498000€
# Not installed
# 450000€
# Hyper equipped
# 449000€
# 285000€
# 299000€
# Hyper equipped
# 1321335€
# Installed
# 89000€
# 89000€
# 179000€
# 450000€
# 429000€
# 550000€
# 545000€
# Not installed
# 535000€
# Installed
# 299000€
# Semi equipped
# 570000€
# Semi equipped
# 209000€
# Not installed
# 339000€
# Semi equipped
# 229000€
# Installed
# 985000€
# 145000€
# 1495000€
# Hyper equipped
# 535000€
# Installed
# 649000€
# Hyper equipped
# 279000€
# Installed
# 695000€
# Installed
# 695000€
# Installed
# 215000€
# Installed
# 240000€
# Installed
# 289000€
# Installed
# 325000€
# Installed
# 435000€
# 650000€
# Hyper equipped
# From 235000€ To 340000€
# From 348000€ To 379000€
# 369900€
# From 379000€ To 388000€
# From 390000€ To 539000€
# 439000€
# From 716000€ To 765000€
# 215000€
# Installed
# 240000€
# Semi equipped
# 260000€
# Installed
# 359000€
# USA installed
# 415000€
# Not installed
# 475000€
# Semi equipped
# 349000€
# Installed
# 419000€
# Installed
# 580000€
# Installed
# 875000€
# Installed
# 189500€
# 259000€
# 499000€
# Installed
# 270189€
# 285000€
# Installed
# 285000€
# Installed
# 299000€
# Hyper equipped
# 285000€
# 285000€
# 245632€
# 425000€
# 230000€
# 1050000€
# From 208000€ To 404000€
# 149000€
# 595000€
# 170000€
# Installed
# 290000€
# 449000€
# 1250000€
# Hyper equipped
# 410000€
# Installed
# 140000€
# Semi equipped
# 264044€
# 1795000€
# Hyper equipped
# 234000€
# 425000€
# 479000€
# Installed
# 149000€
# 379000€
# Installed
# 349000€
# Installed
# 1645000€
# 325000€
# 350000€
# Hyper equipped
# 465000€
# 545000€
# Hyper equipped
# 209000€
# Installed
# 695000€
# Hyper equipped
# 1095000€
# Hyper equipped
# 235000€
# Installed
# 775000€
# Hyper equipped
# 1690000€
# Hyper equipped
# 250000€
# Installed
# 575000€
# Hyper equipped
# 225000€
# Installed
# 298000€
# Installed
# 349000€
# 450000€
# Hyper equipped
# 750000€
# USA hyper equipped
# 899000€
# 310000€
# Hyper equipped
# 345000€
# Semi equipped
# 350000€
# 350000€
# 385000€
# 395000€
# Hyper equipped
# 425000€
# Semi equipped
# 425000€
# Semi equipped
# 139000€
# Semi equipped
# 299000€
# Installed
# 79000€
# Semi equipped
# 379000€
# Installed
# 300000€
# USA installed
# 325000€
# Installed
# 325000€
# From 229000€ To 597000€
# 495000€
# From 229000€ To 597000€
# From 359000€ To 379000€
# 399000€
# Installed
# 379000€
# USA hyper equipped
# 395000€
# USA installed
# 548000€
# Hyper equipped
# 289000€
# 224900€
# 325000€
# 395000€
# Semi equipped
# 265000€
# Installed
# 175000€
# 127000€
# Installed
# 535000€
# Hyper equipped
# 450000€
# Installed
# 395000€
# Hyper equipped
# 545000€
# Semi equipped
# 149000€
# Hyper equipped
# 249950€
# Installed
# 847000€
# Hyper equipped
# 3500000€
# Hyper equipped
# 285000€
# 325000€
# Installed
# 149000€
# 149000€
# 90000€
# USA installed
# 299000€
# Installed
# 665000€
# From 156784€ To 875830€
# From 200000€ To 290000€
# From 212000€ To 325000€
# From 215000€ To 430000€
# From 235000€ To 340000€
# From 236000€ To 410000€
# From 286033€ To 333550€
# From 291500€ To 426500€
# From 291500€ To 426500€
# From 299250€ To 364250€
# 369000€
# From 379000€ To 388966€
# From 389500€ To 520000€
# From 441648€ To 445428€
# From 479000€ To 515000€
# From 480000€ To 485000€
# From 498000€ To 585000€
# From 575000€ To 599000€
# 135000€
# 219000€
# Installed
# 219000€
# Installed
# 419000€
# Installed
# 299000€
# Installed
# 1380000€
# Hyper equipped
# 339000€
# Hyper equipped
# 1195000€
# Hyper equipped
# 289000€
# Installed
# 395000€
# 230000€
# Installed
# 349000€
# Semi equipped
# 269000€
# Semi equipped
# 230000€
# 730000€
# Installed
# 348000€
# Semi equipped
# 348000€
# Semi equipped
# 299000€
# Installed
# 130000€
# Semi equipped
# 528000€
# Installed
# 295000€
# Hyper equipped
# 775000€
# Hyper equipped
# 285000€
# Semi equipped
# 219000€
# Hyper equipped
# 109000€
# Installed
# 269000€
# 259000€
# Installed
# 435000€
# 330000€
# Not installed
# 359000€
# Hyper equipped
# 499000€
# Installed
# 669000€
# 359000€
# Hyper equipped
# 85000€
# 199990€
# 219000€
# Hyper equipped
# 199990€
# 430000€
# 399000€
# 575000€
# Semi equipped
# 475000€
# Installed
# 790000€
# 225000€
# Hyper equipped
# 300000€
# Hyper equipped
# 285000€
# Semi equipped
# 165000€
# Semi equipped
# 165000€
# Semi equipped
# 348000€
# Installed
# 349000€
# Semi equipped
# 359000€
# Hyper equipped
# 590000€
# Installed
# 670000€
# Not installed
# 695000€
# Installed
# 895000€
# Installed
# 945000€
# Hyper equipped
# 170000€
# Installed
# 179000€
# Semi equipped
# 195000€
# Hyper equipped
# 269000€
# 345000€
# Installed
# 415000€
# Semi equipped
# 660000€
# Not installed
# 195000€
# Semi equipped
# 225000€
# Semi equipped
# 139000€
# Not installed
# 269900€
# Installed
# 149000€
# Not installed
# 249000€
# Installed
# 335000€
# Hyper equipped
# 160000€
# Installed
# 625000€
# 595000€
# Hyper equipped
# 390000€
# Hyper equipped
# 595000€
# Hyper equipped
# 595000€
# Hyper equipped
# 290000€
# Hyper equipped
# 185000€
# Installed
# 259000€
# 250000€
# Installed
# 499000€
# 169000€
# 70000€
# Not installed
# From 253000€ To 290000€
# From 327000€ To 547000€
# 547000€
# Hyper equipped
# 327000€
# Hyper equipped
# 315000€
# Installed
# 825000€
# 620000€
# Hyper equipped
# 220000€
# Semi equipped
# 299000€
# Installed
# 225000€
# Installed
# From 225000€ To 525000€
# From 315000€ To 406000€
# 595000€
# Hyper equipped
# 498000€
# Installed
# 179000€
# Semi equipped
# 335000€
# 330000€
# Semi equipped
# From 279500€ To 289500€
# 215000€
# Semi equipped
# 224000€
# Installed
# 225000€
# Installed
# 293000€
# Installed
# 334000€
# USA hyper equipped
# 362500€
# Hyper equipped
# 375000€
# 410000€
# Installed
# 499000€
# Installed
# 620000€
# 450000€
# Semi equipped
# 1150000€
# Semi equipped
# From 149000€ To 382000€
# From 235000€ To 459000€
# From 240000€ To 528000€
# From 245000€ To 295000€
# From 260000€ To 465000€
# From 260000€ To 450000€
# 260000€
# From 260000€ To 450000€
# From 262000€ To 299500€
# From 270000€ To 995000€
# From 320000€ To 850000€
# From 323500€ To 387500€
# From 325000€ To 366000€
# From 327000€ To 403000€
# 335000€
# From 340000€ To 1435000€
# From 350000€ To 379000€
# From 355000€ To 374000€
# 279500€
# Hyper equipped
# 335000€
# Installed
# 275000€
# Installed
# 129000€
# 775000€
# 169900€
# Semi equipped
# 325000€
# 429000€
# 429000€
# Hyper equipped
# 429000€
# Hyper equipped
# 535000€
# Installed
# 20000€ + 356€ per month
# Semi equipped
# 569000€
# 495000€
# 228000€
# Hyper equipped
# 245000€
# 235000€
# Installed
# 249900€
# Installed
# 365000€
# Semi equipped
# 353976€
# 1625000€
# Hyper equipped
# 595000€
# Installed
# 169000€
# Semi equipped
# 353000€
# Hyper equipped
# 349000€
# Installed
# 314000€
# Hyper equipped
# 260250€
# Installed
# 360000€
# Installed
# 329000€
# Hyper equipped
# 332000€
# Hyper equipped
# 355000€
# From 364000€ To 379000€
# 365000€
# From 367000€ To 444000€
# From 400000€ To 450000€
# From 400000€ To 450000€
# From 407000€ To 443000€
# From 429250€ To 439750€
# From 435000€ To 459000€
# From 467000€ To 547500€
# From 615000€ To 765000€
# From 774500€ To 808500€
# From 1200000€ To 1375000€
# 189000€
# Installed
# 265000€
# Semi equipped
# 275000€
# Semi equipped
# 420000€
# Semi equipped
# 436000€
# 298500€
# Semi equipped
# 365000€
# Semi equipped
# 365000€
# Semi equipped
# 395000€
# Installed
# 990000€
# Hyper equipped
# 185000€
# Installed
# 195000€
# Installed
# 395000€
# Installed
# 605250€
# Hyper equipped
# 105000€
# 117800€
# Hyper equipped
# 239000€
# Installed
# 465000€
# Installed
# From 276500€ To 332000€
# From 360000€ To 430000€
# From 318000€ To 465000€
# 318000€
# Installed
# From 260250€ To 304000€
# 320000€
# Installed
# 317000€
# Hyper equipped
# 465000€
# Installed
# 349000€
# 335000€
# Installed
# 265250€
# Installed
# 289580€
# Installed
# From 286000€ To 462000€
# 344000€
# Hyper equipped
# 299000€
# Hyper equipped
# 276500€
# Hyper equipped
# 299000€
# Hyper equipped
# 430000€
# Installed
# 344000€
# Hyper equipped
# 286000€
# Hyper equipped
# 462000€
# Hyper equipped
# 260250€
# Installed
# 304000€
# Installed
# 330000€
# Installed
# 549000€
# 925000€
# USA uninstalled
# 549000€
# 925000€
# USA uninstalled
# 925000€
# USA uninstalled
# 250000€
# Not installed
# 499000€
# 234500€
# Installed
# 325000€
# Installed
# 325000€
# Installed
# 495000€
# Installed
# 119000€
# Semi equipped
# 210000€
# Installed
# 214000€
# Installed
# 225000€
# Installed
# 275000€
# Installed
# 275000€
# Installed
# 284000€
# Installed
# 325000€
# Installed
# 356000€
# USA hyper equipped
# 648000€
# Installed
# 650000€
# Hyper equipped
# 239000€
# Installed
# 259000€
# 299900€
# Installed
# 424000€
# 440000€
# Installed
# 465000€
# Installed
# 485000€
# Hyper equipped
# 695000€
# Installed
# 240000€
# Semi equipped
# 265000€
# Not installed
# 269000€
# Semi equipped
# 299000€
# Hyper equipped
# 299850€
# Installed
# 1150000€
# 139000€
# 305000€
# 179000€
# Installed
# 298000€
# Installed
# 325000€
# 549000€
# Hyper equipped
# 265000€
# USA semi equipped
# 349000€
# Installed
# 574000€
# Installed
# 550000€
# 399000€
# 126000€
# Not installed
# 625000€
# Semi equipped
# 599000€
# Not installed
# 389900€
# Hyper equipped
# 389900€
# Hyper equipped
# 479000€
# Installed
# 274000€
# Installed
# 220000€
# 220000€
# 299000€
# 1475000€
# Hyper equipped
# 1085000€
# Semi equipped
# 239000€
# 649000€
# 399000€
# 195000€
# 369000€
# 329000€
# 325000€
# Installed
# 1150000€
# Installed
# 310000€
# USA installed
# 2815000€
# 149000€
# Semi equipped
# 213000€
# Semi equipped
# 219000€
# Installed
# 480000€
# Installed
# 598500€
# Hyper equipped
# 199000€
# Installed
# 199000€
# Installed
# 210000€
# Semi equipped
# 269000€
# Hyper equipped
# 270000€
# Installed
# 290000€
# 295000€
# Installed
# 375000€
# Hyper equipped
# 428000€
# Hyper equipped
# 930000€
# Hyper equipped
# 169000€
# Installed
# 189000€
# 435000€
# Hyper equipped
# 389000€
# USA installed
# From 182000€ To 390000€
# From 220000€ To 515000€
# From 239000€ To 346000€
# From 246000€ To 305000€
# From 249000€ To 449000€
# From 269000€ To 331000€
# From 279600€ To 329800€
# 309500€
# USA uninstalled
# 490000€
# 375000€
# From 321942€ To 402075€
# 995000€
# 849000€
# Hyper equipped
# 149000€
# Semi equipped
# 280000€
# Semi equipped
# 595000€
# Hyper equipped
# 115000€
# 290000€
# Not installed
# 320000€
# Not installed
# 227000€
# Semi equipped
# 545000€
# Hyper equipped
# 279000€
# Hyper equipped
# 169000€
# Installed
# 329000€
# 230000€
# Installed
# 249000€
# Installed
# 220000€
# Installed
# 549000€
# Hyper equipped
# 165000€
# 278843€
# Hyper equipped
# 399000€
# Hyper equipped
# 729000€
# 339000€
# 299900€
# Installed
# 229900€
# 240000€
# Installed
# 439000€
# Hyper equipped
# From 286000€ To 462000€
# From 305000€ To 395000€
# From 319000€ To 339000€
# From 325000€ To 385000€
# From 346000€ To 490000€
# From 399000€ To 699000€
# From 406000€ To 450000€
# From 430000€ To 449000€
# From 450000€ To 525000€
# From 454458€ To 631481€
# From 575000€ To 599000€
# 199000€
# Installed
# 219000€
# 110000€
# Not installed
# 325000€
# 415000€
# Not installed
# 445000€
# Installed
# 485000€
# Installed
# 790000€
# 145000€
# 155000€
# 155000€
# 170000€
# 310000€
# Semi equipped
# 325000€
# 449000€
# Installed
# 699000€
# Installed
# 150000€
# Semi equipped
# 439000€
# 764000€
# Installed
# 70000€
# Semi equipped
# 335000€
# 245000€
# Installed
# 289500€
# Hyper equipped
# 1480000€
# 519000€
# Semi equipped
# 529000€
# 540000€
# Installed
# 220000€
# Installed
# 199000€
# Not installed
# 2475000€
# Hyper equipped
# 650000€
# Semi equipped
# 299000€
# 362500€
# Hyper equipped
# 299000€
# Semi equipped
# 350000€
# Installed
# 258000€
# 539000€
# Not installed
# 579000€
# Installed
# 409000€
# Hyper equipped
# 335000€
# Installed
# 229000€
# Installed
# 224000€
# Installed
# 362500€
# Hyper equipped
# 299000€
# Semi equipped
# 299000€
# Semi equipped
# 549000€
# Hyper equipped
# 285000€
# Installed
# 675000€
# 355000€
# 199000€
# Installed
# 169000€
# Installed
# 259500€
# Installed
# 299000€
# Semi equipped
# 299000€
# Installed
# 499000€
# Hyper equipped
# 545000€
# Installed
# 164500€
# Installed
# 189000€
# Semi equipped
# 290000€
# Installed
# 325000€
# Installed
# 348500€
# Semi equipped
# 430000€
# Semi equipped
# 685000€
# Hyper equipped
# 305000€
# Installed
# 386000€
# Installed
# 399000€
# Hyper equipped
# 399000€
# Hyper equipped
# 465000€
# Hyper equipped
# 535000€
# Hyper equipped
# 775000€
# Hyper equipped
# 179000€
# Semi equipped
# 289000€
# Installed
# 399000€
# Semi equipped
# 455000€
# Installed
# 660000€
# Semi equipped
# 665000€
# 225000€
# 349000€
# 389000€
# 349000€
# USA installed
# 280000€
# Installed
# 329000€
# Not installed
# 198000€
# 268000€
# Installed
# From 455600€ To 542214€
# 299850€
# Installed
# 170000€
# Semi equipped
# 215000€
# 135000€
# 295000€
# Installed
# 319000€
# Installed
# From 299500€ To 319000€
# 299500€
# Installed
# 625000€
# Installed
# 250000€
# Installed
# 775000€
# Hyper equipped
# 569000€
# 429000€
# 144000€
# Semi equipped
# 240000€
# Semi equipped
# 469000€
# 315000€
# Semi equipped
# 150000€
# Installed
# 480000€
# Installed
# 415000€
# Hyper equipped
# 215000€
# Installed
# 285000€
# Installed
# 450000€
# Semi equipped
# 220000€
# USA hyper equipped
# 465000€
# Installed
# 595000€
# 850000€
# Hyper equipped
# 850000€
# Hyper equipped
# 1099000€
# Installed
# 320000€
# Semi equipped
# 119000€
# Installed
# 149000€
# Semi equipped
# 225000€
# 229000€
# Installed
# 270000€
# Installed
# 280000€
# Installed
# 299000€
# Installed
# 369000€
# Hyper equipped
# 3700000€
# Installed
# 365000€
# USA hyper equipped
# 249000€
# Installed
# 119000€
# Not installed
# 449000€
# Hyper equipped
# 159000€
# Installed
# 220000€
# Hyper equipped
# 229000€
# Semi equipped
# 250000€
# 260000€
# 269000€
# Hyper equipped
# 355000€
# Not installed
# 375000€
# Installed
# 383000€
# Installed
# 950000€
# Installed
# 518000€
# Semi equipped
# From 347400€ To 394600€
# 169000€
# 265000€
# 290000€
# 398000€
# 259000€
# 120000€
# 338990€
# 80000€
# Semi equipped
# 165000€
# 975000€
# 285000€
# 5900000€
# Hyper equipped
# 110000€
# Not installed
# 345000€
# 449000€
# Semi equipped
# 245000€
# 299000€
# 215000€
# Semi equipped
# 189000€
# 439000€
# Hyper equipped
# 565000€
# 250000€
# Semi equipped
# 250000€
# Semi equipped
# 264000€
# USA installed
# 349000€
# Installed
# 545000€
# Installed
# 398000€
# 535000€
# Hyper equipped
# 130000€
# Semi equipped
# 165000€
# 224000€
# Installed
# 229500€
# Installed
# 265000€
# Installed
# 380000€
# Installed
# 675000€
# Hyper equipped
# 395000€
# 395000€
# Installed
# 669000€
# Semi equipped
# 985000€
# From 195000€ To 445000€
# From 232000€ To 465000€
# From 235000€ To 459000€
# From 235000€ To 390000€
# From 235000€ To 390000€
# From 255000€ To 550000€
# From 274000€ To 339000€
# From 298000€ To 379000€
# From 315000€ To 480000€
# From 327000€ To 330000€
# From 340000€ To 1600000€
# From 344000€ To 459000€
# From 346067€ To 412638€
# From 348000€ To 379000€
# 364000€
# From 398000€ To 524000€
# 427000€
# From 435000€ To 446000€
# 545000€
# 525000€
# Installed
# 100000€
# Not installed
# 1100000€
# 289000€
# 365000€
# Installed
# 389000€
# 249000€
# 849000€
# Installed
# 105000€
# Installed
# 249900€
# 195000€
# Installed
# 375000€
# Installed
# 2500000€
# 369000€
# Semi equipped
# 335000€
# Installed
# 375000€
# Installed
# 219000€
# Installed
# 214000€
# Semi equipped
# 419000€
# Hyper equipped
# 475000€
# Installed
# 275000€
# Installed
# 229000€
# Hyper equipped
# 185000€
# Hyper equipped
# 589000€
# Hyper equipped
# 265000€
# Installed
# 145000€
# Installed
# 209000€
# Semi equipped
# 189000€
# Installed
# 1699000€
# 358000€
# Installed
# 335000€
# Installed
# 525000€
# Installed
# 595000€
# Hyper equipped
# 148000€
# Installed
# 249000€
# Installed
# 330000€
# Hyper equipped
# 330000€
# 345000€
# Semi equipped
# 425000€
# Installed
# 449000€
# Installed
# 199000€
# Installed
# 240000€
# Installed
# 249000€
# Semi equipped
# 369000€
# 549000€
# Semi equipped
# 395000€
# Installed
# 169000€
# 429000€
# 310000€
# Semi equipped
# 400000€
# Semi equipped
# 520000€
# Installed
# 649000€
# Installed
# 795000€
# Installed
# 135000€
# 176000€
# Semi equipped
# 249000€
# Semi equipped
# 395000€
# Installed
# 469000€
# 535000€
# Hyper equipped
# 649000€
# Hyper equipped
# 845000€
# 430000€
# 595000€
# Hyper equipped
# 235000€
# Installed
# 404500€
# Hyper equipped
# 407000€
# Hyper equipped
# 2200000€
# Hyper equipped
# From 404500€ To 450000€
# 249000€
# Installed
# 459000€
# Hyper equipped
# 409500€
# Hyper equipped
# 424000€
# 447000€
# Hyper equipped
# 427000€
# Hyper equipped
# 406000€
# Hyper equipped
# 417000€
# Hyper equipped
# From 273700€ To 382150€
# 450000€
# Hyper equipped
# 442000€
# Hyper equipped
# 265000€
# Installed
# 199000€
# 425000€
# 547000€
# Hyper equipped
# 327000€
# Hyper equipped
# From 273700€ To 382500€
# From 159325€ To 447375€
# From 159325€ To 447375€
# 370000€
# Hyper equipped
# 530328€
# Hyper equipped
# 365000€
# Hyper equipped
# 397000€
# Hyper equipped
# 269000€
# Installed
# 310000€
# Semi equipped
# 585000€
# Installed
# 89000€
# 130000€
# 149000€
# Installed
# 279000€
# From 225000€ To 525000€
# From 253000€ To 290000€
# From 279500€ To 289500€
# From 315000€ To 406000€
# From 409000€ To 415000€
# 365000€
# Hyper equipped
# 370000€
# Hyper equipped
# 375000€
# Hyper equipped
# 376000€
# Hyper equipped
# 397000€
# Hyper equipped
# 404500€
# Hyper equipped
# 406000€
# Hyper equipped
# 407000€
# Hyper equipped
# 409500€
# Hyper equipped
# 417000€
# Hyper equipped
# 427000€
# Hyper equipped
# 442000€
# Hyper equipped
# 450000€
# Hyper equipped
# 259000€
# Installed
# 795000€
# Hyper equipped
# 245000€
# Installed
# 448000€
# Installed
# 525000€
# Not installed
# 429172€
# Hyper equipped
# From 365000€ To 397000€
# 419368€
# Hyper equipped
# 390260€
# Hyper equipped
# 419368€
# Hyper equipped
# 301948€
# Hyper equipped
# 530328€
# Hyper equipped
# 556453€
# Hyper equipped
# 375000€
# Hyper equipped
# 429210€
# Hyper equipped
# 429210€
# Hyper equipped
# 376000€
# Hyper equipped
# 419406€
# Hyper equipped
# 393300€
# Hyper equipped
# 367726€
# Hyper equipped
# 463258€
# Hyper equipped
# 595000€
# 249000€
# Hyper equipped
# 525000€
# Hyper equipped
# 296000€
# 30000€
# Installed
# 959000€
# Hyper equipped
# From 301948€ To 556453€
# 429000€
# Installed
# 269000€
# Installed
# 295000€
# Installed
# 235000€
# 95000€
# 185000€
# 535000€
# 780000€
# Hyper equipped
# 798000€
# Hyper equipped
# 1370000€
# Hyper equipped
# 275000€
# 289000€
# Installed
# 380000€
# Installed
# 475000€
# Installed
# 595000€
# Installed
# 965000€
# Hyper equipped
# 1275000€
# Hyper equipped
# 142500€
# Installed
# 147500€
# Installed
# 149000€
# Semi equipped
# 289000€
# Installed
# 410000€
# Hyper equipped
# 795000€
# Hyper equipped
# 175000€
# Installed
# 179000€
# Installed
# 199000€
# Installed
# 200000€
# Hyper equipped
# 275000€
# Installed
# 399000€
# Hyper equipped
# 1450000€
# Hyper equipped
# 145000€
# Installed
# 268000€
# Installed
# 285000€
# Semi equipped
# 380000€
# 409000€
# Installed
# 525000€
# 730000€
# Installed
# 545000€
# Hyper equipped
# 548000€
# Hyper equipped
# 389853€
# Hyper equipped
# 269000€
# 535000€
# Hyper equipped
# 519350€
# Installed
# 352366€
# Installed
# 346866€
# Installed
# 289211€
# Installed
# 346179€
# Installed
# 321672€
# Installed
# 330435€
# Installed
# 272423€
# Installed
# 398413€
# Installed
# 310645€
# Installed
# 519350€
# Installed
# 512350€
# Installed
# 526035€
# Installed
# 556386€
# Installed
# 558910€
# Installed
# 337638€
# Installed
# 341464€
# Installed
# 768253€
# Installed
# 308374€
# Installed
# 512350€
# Installed
# 289211€
# Installed
# 370860€
# Installed
# 476924€
# Installed
# 382405€
# Installed
# 455000€
# Installed
# 159000€
# Installed
# 215000€
# Installed
# 225000€
# 260000€
# Installed
# 340000€
# Hyper equipped
# 149900€
# Semi equipped
# 179000€
# Semi equipped
# 184000€
# Semi equipped
# 189000€
# 195000€
# Semi equipped
# 279000€
# Hyper equipped
# 465000€
# Hyper equipped
# 490000€
# Installed
# 549000€
# Semi equipped
# 747000€
# Not installed
# 215000€
# 235000€
# Installed
# 245000€
# Hyper equipped
# 245000€
# Hyper equipped
# 247000€
# Installed
# 275000€
# Semi equipped
# 179000€
# Hyper equipped
# 260000€
# Installed
# 265000€
# Installed
# 375000€
# 529000€
# Semi equipped
# 529000€
# Semi equipped
# 599900€
# 210000€
# Hyper equipped
# 295000€
# Installed
# 245000€
# 498000€
# 498000€
# 429000€
# 375000€
# 699000€
# Installed
# 399000€
# Installed
# 549000€
# 380000€
# 199000€
# 249000€
# 485000€
# 395000€
# 780000€
# 720000€
# 358000€
# 290000€
# 525000€
# Installed
# 209000€
# From 419000€ To 457000€
# 1380000€
# Hyper equipped
# 219000€
# 469000€
# 455000€
# 375000€
# 575000€
# 175000€
# 349576€
# 898000€
# Installed
# 1845000€
# Hyper equipped
# 359000€
# Hyper equipped
# From 235000€ To 459000€
# From 235000€ To 390000€
# 260000€
# From 260000€ To 360000€
# From 264000€ To 308000€
# From 264000€ To 304000€
# From 265000€ To 570000€
# From 295000€ To 425000€
# From 364163€ To 388789€
# From 398175€ To 431925€
# From 399000€ To 510000€
# 129000€
# Not installed
# 229000€
# Installed
# 229000€
# Installed
# 315000€
# Installed
# 399500€
# Installed
# 499000€
# 315000€
# 499000€
# 695000€
# Installed
# 369000€
# Installed
# 379000€
# Installed
# 1375000€
# Hyper equipped
# 169000€
# 189000€
# 259000€
# Installed
# 265000€
# 455000€
# Hyper equipped
# 650000€
# Installed
# 350000€
# 275000€
# 259000€
# 349000€
# 459000€
# 520000€
# 520000€
# 369000€
# 210000€
# 265000€
# Installed
# 155000€
# Not installed
# 160000€
# Installed
# 169000€
# Installed
# 259500€
# Installed
# 620000€
# 449000€
# Installed
# 449000€
# Hyper equipped
# 329000€
# Installed
# 399000€
# Hyper equipped
# 799000€
# Installed
# 659500€
# Installed
# 559700€
# Installed
# 529000€
# Installed
# 780775€
# 819000€
# Installed
# From 458000€ To 465000€
# From 679000€ To 725000€
# From 409000€ To 415000€
# 650000€
# Hyper equipped
# 294000€
# Installed
# 895000€
# USA hyper equipped
# 222000€
# 280000€
# Hyper equipped
# 525000€
# 775000€
# Hyper equipped
# 1295000€
# 1370000€
# 249000€
# Installed
# 295000€
# Semi equipped
# 329000€
# Installed
# 429000€
# Installed
# 465000€
# Installed
# 497000€
# 1150000€
# Installed
# 280000€
# Semi equipped
# 395000€
# Installed
# 1300000€
# Installed
# 1365000€
# Hyper equipped
# 420000€
# Hyper equipped
# 495000€
# Hyper equipped
# 495000€
# Hyper equipped
# 199000€
# Installed
# 249000€
# Installed
# 249000€
# 259000€
# Installed
# 345000€
# Not installed
# 349000€
# USA semi equipped
# 420000€
# Semi equipped
# 650000€
# Hyper equipped
# From 482500€ To 528500€
# 279000€
# Installed
# 296000€
# Installed
# 284000€
# Installed
# 312000€
# Installed
# 322000€
# 435000€
# Hyper equipped
# 435000€
# Hyper equipped
# 435000€
# Hyper equipped
# 225000€
# Installed
# 209000€
# Installed
# 375000€
# Installed
# 245000€
# Installed
# 499000€
# Installed
# 189000€
# Installed
# 349500€
# Installed
# 219000€
# Installed
# 215000€
# Semi equipped
# 479000€
# Installed
# 549000€
# Installed
# 275000€
# 449900€
# 450000€
# 410000€
# 165000€
# 334000€
# 169000€
# 215000€
# 215000€
# 215000€
# 215000€
# 575000€
# 650000€
# Hyper equipped
# 699000€
# Installed
# 589000€
# 649000€
# Hyper equipped
# 190000€
# Hyper equipped
# 194000€
# Installed
# 205000€
# Hyper equipped
# 215000€
# Installed
# 215000€
# Installed
# 224900€
# Installed
# 270000€
# Hyper equipped
# 1695000€
# Hyper equipped
# 390000€
# 1490000€
# Semi equipped
# 679000€
# Installed
# 750000€
# Hyper equipped
# 159000€
# Semi equipped
# 195000€
# 220000€
# Semi equipped
# 335000€
# Installed
# 695000€
# Hyper equipped
# 179000€
# Installed
# 194000€
# Installed
# 199000€
# Installed
# 249500€
# Semi equipped
# 255000€
# Installed
# 258500€
# 295000€
# Installed
# 339000€
# Installed
# 225000€
# 385000€
# Installed
# 385000€
# 399000€
# 369000€
# 440000€
# Installed
# 395500€
# 697500€
# Installed
# 1195000€
# 419600€
# 460000€
# 386000€
# 149000€
# Semi equipped
# 320000€
# Installed
# 145000€
# 320000€
# 439000€
# 350000€
# Hyper equipped
# 436292€
# From 370000€ To 396000€
# 259000€
# 319000€
# 685000€
# Installed
# 130000€
# 275000€
# 210000€
# Hyper equipped
# 259000€
# 395804€
# 393804€
# 392709€
# 630000€
# Installed
# 680000€
# Installed
# 680000€
# Installed
# 695000€
# Installed
# 695000€
# Installed
# 999900€
# Semi equipped
# 139000€
# 219000€
# 225000€
# 225000€
# 275000€
# Semi equipped
# 399000€
# Installed
# 399000€
# Semi equipped
# 3990000€
# USA hyper equipped
# 220000€
# 349000€
# 498000€
# Semi equipped
# 619000€
# Installed
# 1150000€
# Hyper equipped
# 1690000€
# 4000000€
# Hyper equipped
# 197000€
# 324000€
# Installed
# 425000€
# 435000€
# Installed
# 460000€
# Hyper equipped
# 176000€
# Semi equipped
# 369000€
# 345000€
# Hyper equipped
# 685000€
# Installed
# 424900€
# 388900€
# 390824€
# 328168€
# 371608€
# 348750€
# 235000€
# 329000€
# 185000€
# 157000€
# Installed
# 300000€
# 429000€
# 447000€
# 299900€
# 915000€
# 399000€
# 189500€
# 197000€
# Hyper equipped
# 229000€
# Installed
# 280000€
# Installed
# 2999000€
# 975000€
# 265000€
# 239000€
# 329000€
# Hyper equipped
# 305000€
# 179000€
# 315000€
# Installed
# 145000€
# 145000€
# 215000€
# 265000€
# Installed
# 299000€
# Installed
# 675000€
# Hyper equipped
# 189000€
# 214000€
# 284000€
# Installed
# 317900€
# Installed
# 375000€
# 950000€
# Hyper equipped
# From 380000€ To 425000€
# 399000€
# From 575000€ To 954810€
# 295000€
# 329000€
# Hyper equipped
# 339000€
# Installed
# 415000€
# Installed
# 595000€
# Installed
# 595000€
# Installed
# 875000€
# Hyper equipped
# 875000€
# Hyper equipped
# 2695000€
# Hyper equipped
# 265000€
# Installed
# 170000€
# Installed
# 239000€
# 395000€
# Installed
# 405000€
# Installed
# 595000€
# 740000€
# Hyper equipped
# 770000€
# Hyper equipped
# 145000€
# 130000€
# 395000€
# 319000€
# 135000€
# 185000€
# 298000€
# 462000€
# Hyper equipped
# 375000€
# Hyper equipped
# 310000€
# 349000€
# 176500€
# Hyper equipped
# 485000€
# 317000€
# 979000€
# 399000€
# 659000€
# 550000€
# 299000€
# 260000€
# Installed
# 259000€
# Hyper equipped
# 475000€
# Installed
# 315000€
# Hyper equipped
# 495000€
# Hyper equipped
# 179000€
# 305000€
# Semi equipped
# 650000€
# Hyper equipped
# 650000€
# Hyper equipped
# 260000€
# 395000€
# Semi equipped
# 1875000€
# 169000€
# Installed
# 305000€
# Hyper equipped
# 337500€
# 375000€
# 375000€
# 397000€
# Installed
# 499000€
# Hyper equipped
# 345000€
# Installed
# 799500€
# Hyper equipped
# 460000€
# Hyper equipped
# 170000€
# Semi equipped
# 199500€
# Installed
# 245000€
# Installed
# 249000€
# Installed
# 379000€
# 425000€
# Not installed
# 425000€
# Not installed
# 429900€
# Hyper equipped
# 545000€
# Installed
# 850000€
# Not installed
# 1490000€
# Installed
# 1490000€
# Installed
# 945000€
# Installed
# 185000€
# 450000€
# Installed
# 275000€
# Hyper equipped
# 300000€
# 325000€
# Installed
# 600000€
# Installed
# 230000€
# 1690000€
# Hyper equipped
# From 347000€ To 449000€
# 239000€
# Semi equipped
# 1100000€
# Installed
# 329000€
# 549000€
# Installed
# 265000€
# 285000€
# 270000€
# 239000€
# 240000€
# Installed
# 1200000€
# Hyper equipped
# 1200000€
# Hyper equipped
# 229000€
# From 310000€ To 400000€
# From 310000€ To 400000€
# From 310000€ To 400000€
# From 498000€ To 585000€
# 130000€
# Installed
# 105000€
# Installed
# 295000€
# 249900€
# 275000€
# 330000€
# Installed
# 375000€
# 449000€
# Installed
# 224000€
# Installed
# 199900€
# Installed
# 785000€
# 600000€
# Installed
# 600000€
# Installed
# 239000€
# Installed
# 245000€
# Semi equipped
# 255000€
# Semi equipped
# 255000€
# Semi equipped
# 475000€
# Installed
# 555000€
# Installed
# 679000€
# Installed
# 685000€
# Installed
# From 245000€ To 560000€
# 345000€
# 135000€
# Not installed
# 225000€
# Semi equipped
# 369000€
# Hyper equipped
# 495000€
# 545000€
# 545000€
# 850000€
# 895000€
# Hyper equipped
# 238000€
# Hyper equipped
# 170000€
# Installed
# 205000€
# Semi equipped
# 249000€
# 249000€
# Installed
# 250000€
# Installed
# 259000€
# Semi equipped
# 285000€
# Installed
# 319000€
# Installed
# 345000€
# 399000€
# Semi equipped
# 327900€
# 649000€
# Hyper equipped
# From 224000€ To 379000€
# 350000€
# 289000€
# Installed
# 350000€
# 189000€
# Installed
# 510000€
# USA installed
# 419000€
# 279000€
# Semi equipped
# 395000€
# Not installed
# 89000€
# 475000€
# 450000€
# Hyper equipped
# 249000€
# Installed
# 378000€
# Installed
# 299000€
# Installed
# 391665€
# 325000€
# Installed
# 149000€
# 495000€
# Installed
# 499000€
# 499000€
# 154000€
# Semi equipped
# 850000€
# Installed
# 649000€
# Hyper equipped
# 339000€
# Installed
# 295000€
# Installed
# 298000€
# Hyper equipped
# 779000€
# Installed
# 915000€
# Installed
# 184000€
# Installed
# 184900€
# Installed
# 259000€
# Installed
# 269000€
# USA hyper equipped
# 465000€
# Installed
# 169000€
# Installed
# 358000€
# Hyper equipped
# 375000€
# 459000€
# Semi equipped
# 945000€
# Hyper equipped
# 945000€
# Hyper equipped
# 945000€
# Hyper equipped
# 230000€
# 250000€
# 285000€
# 295000€
# 697500€
# Hyper equipped
# 199000€
# Semi equipped
# 290000€
# 297000€
# Installed
# 299000€
# Installed
# 419000€
# Semi equipped
# 549000€
# Installed
# 1695000€
# 158000€
# Installed
# 179000€
# Semi equipped
# 310000€
# 325000€
# 499000€
# Hyper equipped
# 265000€
# Not installed
# 439000€
# Not installed
# 150500€
# 209900€
# Installed
# 170000€
# 225000€
# 845000€
# 449000€
# Installed
# 695000€
# 695000€
# 521030€
# 469000€
# 521030€
# Installed
# 521030€
# Installed
# 521030€
# Installed
# 439000€
# Not installed
# 635000€
# Hyper equipped
# 1050000€
# Installed
# 1185000€
# Semi equipped
# 370000€
# Semi equipped
# 149000€
# 119000€
# 385000€
# 344900€
# Installed
# 115000€
# 219000€
# Semi equipped
# 265000€
# Installed
# 399000€
# Installed
# 225000€
# Semi equipped
# 349000€
# Semi equipped
# 399000€
# Installed
# 410000€
# Semi equipped
# 479000€
# Semi equipped
# 875000€
# Hyper equipped
# 1150000€
# 229000€
# Installed
# 1995000€
# Installed
# 1995000€
# Installed
# 315000€
# Installed
# 119500€
# Semi equipped
# 144800€
# Hyper equipped
# 230000€
# Semi equipped
# 495000€
# USA hyper equipped
# From 291500€ To 426500€
# From 318156€ To 1015215€
# From 339000€ To 355000€
# From 385000€ To 400000€
# 385698€
# From 386000€ To 749000€
# From 499000€ To 525000€
# 239000€
# Installed
# 259000€
# 260000€
# 285000€
# Installed
# 299000€
# Installed
# 375000€
# Installed
# 498000€
# Installed
# 519000€
# Installed
# 550000€
# Installed
# 359000€
# Installed
# 595000€
# Installed
# 235000€
# Installed
# 249000€
# Semi equipped
# 264999€
# 370000€
# Installed
# 545000€
# Semi equipped
# 365000€
# Semi equipped
# 324000€
# Semi equipped
# 269000€
# Installed
# 250000€
# 325000€
# Semi equipped
# 299900€
# Installed
# 299000€
# 98000€
# 543000€
# From 275000€ To 650000€
# 1099000€
# Installed
# 1099000€
# Installed
# 409000€
# Installed
# 369000€
# Semi equipped
# 249000€
# Hyper equipped
# 225000€
# 399988€
# 275000€
# Hyper equipped
# 78000€
# Semi equipped
# 78000€
# Semi equipped
# 375000€
# Semi equipped
# 699000€
# Hyper equipped
# 619000€
# Installed
# 645000€
# Installed
# 119000€
# Installed
# 395000€
# Installed
# 595000€
# Installed
# 595000€
# Installed
# 1195000€
# 120000€
# Installed
# 155000€
# 195000€
# Semi equipped
# 269000€
# Semi equipped
# 269000€
# Semi equipped
# 375000€
# Hyper equipped
# 555000€
# Installed
# 885000€
# Hyper equipped
# 1295000€
# Hyper equipped
# 289000€
# Installed
# 365000€
# Installed
# 200000€
# Installed
# 259000€
# 305000€
# Installed
# 312000€
# Installed
# 329000€
# 335000€
# 449000€
# 590000€
# Installed
# 675000€
# Hyper equipped
# 449000€
# Installed
# 890000€
# Hyper equipped
# 1250000€
# Hyper equipped
# 169000€
# 179000€
# 449000€
# Installed
# 195000€
# 269000€
# 485000€
# 350000€
# 364000€
# 139000€
# Installed
# 460000€
# Semi equipped
# 369000€
# Semi equipped
# 197000€
# 569000€
# Installed
# 629000€
# 365000€
# 427500€
# 55000€
# Semi equipped
# 925000€
# Installed
# 875000€
# Installed
# 975000€
# Installed
# 425000€
# 238000€
# 225000€
# Not installed
# 270000€
# Hyper equipped
# 399000€
# Hyper equipped
# 268000€
# Semi equipped
# 349000€
# Semi equipped
# 265000€
# Installed
# 410000€
# Hyper equipped
# 185000€
# Semi equipped
# 159000€
# Semi equipped
# 220000€
# Installed
# 249000€
# 275000€
# Installed
# 279000€
# Semi equipped
# 289000€
# Hyper equipped
# 295000€
# Installed
# 369000€
# Installed
# 395000€
# Installed
# 690000€
# 1195000€
# Installed
# 325000€
# Hyper equipped
# 350000€
# Hyper equipped
# 570000€
# Semi equipped
# 260000€
# 320000€
# USA installed
# 449000€
# Installed
# 450000€
# Semi equipped
# 480000€
# 485000€
# Installed
# 1650000€
# 199000€
# Installed
# 529000€
# Hyper equipped
# 1180000€
# Installed
# 461300€
# 285000€
# Installed
# 199000€
# 259000€
# Installed
# 349000€
# Installed
# 358000€
# 399000€
# Hyper equipped
# 399000€
# Hyper equipped
# 649000€
# Hyper equipped
# 238000€
# 190000€
# Installed
# 299000€
# 350000€
# 365000€
# 149000€
# Installed
# 385000€
# Installed
# 260000€
# Installed
# 1145000€
# 459000€
# 440000€
# 425000€
# Hyper equipped
# 600000€
# USA installed
# 209000€
# Semi equipped
# 1770000€
# Installed
# 229000€
# Installed
# 139000€
# 490000€
# 45000€
# Not installed
# 490000€
# 175000€
# Semi equipped
# 129000€
# Semi equipped
# 339000€
# Hyper equipped
# 189000€
# Semi equipped
# 425000€
# 85000€
# USA installed
# 240000€
# Semi equipped
# extracted data saved in CSv file
